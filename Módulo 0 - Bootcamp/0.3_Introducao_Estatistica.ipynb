# %% [markdown]
# # BOOTCAMP

# %% [markdown]
# ## Parte 3 - Introdução à Estatística

# %% [markdown]
# ![4 Escalas de Medição.png](data:image/png;base64,...)

# %% [markdown]
# EXEMPLOS
#
# **Categórica**
# Nacionalidade, Preferencia musical, inclinação política
#
# <br>
#
# Péssimo, Ruim, Neutro, Bom, Excelente
# **Ordinal**
#
# <br>
#
# **Intervalar**
# Temperatura em graus celsius, saldo bancário
#
# <br>
#
# **Razão**
# Temperatura em Kelvin (possui zero absoluto), comprimento, peso
